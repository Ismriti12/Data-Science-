# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('C:\\Users\smriti\Documents\DataScience\Chicago_Crime_Detective.csv') 
train
# Out:
# C:\Users\smriti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# ...

# %%
df = pd.DataFrame(train.Date)

df.iloc[len(df)//2 +1]
# Out:
# Date    5/21/06 12:00
# Name: 95821, dtype: object

# %%
type(train['Date'])
# Out:
# pandas.core.series.Series

# %%
month = df["Date"].values

month = [train.split("/")[0] for train in month]
df["month"] = month
print(df["month"])
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 191636     1
# 191637     1
# 191638     1
# 191639     1
# 191640     1
# Name: month, Length: 191641, dtype: object

# %%
train.index = pd.to_datetime(train.Date)

# %%
train.shape
# Out:
# (191641, 10)

# %% [raw]
# train.head()

# %%
train.head()
# Out:
#                      Unnamed: 0       ID            Date  \
# Date
# 2012-12-31 23:15:00           0  8951354  12/31/12 23:15
# 2012-12-31 22:00:00           1  8951141  12/31/12 22:00
# 2012-12-31 22:00:00           2  8952745  12/31/12 22:00
# 2012-12-31 22:00:00           3  8952223  12/31/12 22:00
# 2012-12-31 21:30:00           4  8951608  12/31/12 21:30
#
#                                LocationDescription  Arrest  Domestic  Beat  \
# Date
# 2012-12-31 23:15:00                         STREET   False     False   623
# 2012-12-31 22:00:00                         STREET   False     False  1213
# 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)   False     False  1622
# 2012-12-31 22:00:00                         STREET   False     False   724
# 2012-12-31 21:30:00                         STREET   False     False   211
#
#                     District CommunityArea  Year
# Date
# 2012-12-31 23:15:00        6            69  2012
# 2012-12-31 22:00:00       12            24  2012
# ...

# %%
a= train['Beat']
a
# Out:
# Date
# 2012-12-31 23:15:00     623
# 2012-12-31 22:00:00    1213
# 2012-12-31 22:00:00    1622
# 2012-12-31 22:00:00     724
# 2012-12-31 21:30:00     211
#                        ...
# 2001-01-01 00:05:00    1123
# 2001-01-01 00:01:00    2023
# 2001-01-01 00:01:00     911
# 2001-01-01 00:01:00    1712
# 2001-01-01 00:01:00    1911
# Name: Beat, Length: 191641, dtype: int64

# %%
train.append(month)
# Out:
#                        0 Arrest    Beat CommunityArea            Date  \
# 2012-12-31 23:15:00  NaN  False   623.0            69  12/31/12 23:15
# 2012-12-31 22:00:00  NaN  False  1213.0            24  12/31/12 22:00
# 2012-12-31 22:00:00  NaN  False  1622.0            11  12/31/12 22:00
# 2012-12-31 22:00:00  NaN  False   724.0            67  12/31/12 22:00
# 2012-12-31 21:30:00  NaN  False   211.0            35  12/31/12 21:30
# ...                  ...    ...     ...           ...             ...
# 191636                 1    NaN     NaN           NaN             NaN
# 191637                 1    NaN     NaN           NaN             NaN
# 191638                 1    NaN     NaN           NaN             NaN
# 191639                 1    NaN     NaN           NaN             NaN
# 191640                 1    NaN     NaN           NaN             NaN
#
#                     District Domestic         ID  \
# 2012-12-31 23:15:00        6    False  8951354.0
# ...

# %%
train.head()
# Out:
#                      Unnamed: 0       ID            Date  \
# Date
# 2012-12-31 23:15:00           0  8951354  12/31/12 23:15
# 2012-12-31 22:00:00           1  8951141  12/31/12 22:00
# 2012-12-31 22:00:00           2  8952745  12/31/12 22:00
# 2012-12-31 22:00:00           3  8952223  12/31/12 22:00
# 2012-12-31 21:30:00           4  8951608  12/31/12 21:30
#
#                                LocationDescription  Arrest  Domestic  Beat  \
# Date
# 2012-12-31 23:15:00                         STREET   False     False   623
# 2012-12-31 22:00:00                         STREET   False     False  1213
# 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)   False     False  1622
# 2012-12-31 22:00:00                         STREET   False     False   724
# 2012-12-31 21:30:00                         STREET   False     False   211
#
#                     District CommunityArea  Year
# Date
# 2012-12-31 23:15:00        6            69  2012
# 2012-12-31 22:00:00       12            24  2012
# ...

# %%
df.head()
# Out:
#              Date month
# 0  12/31/12 23:15    12
# 1  12/31/12 22:00    12
# 2  12/31/12 22:00    12
# 3  12/31/12 22:00    12
# 4  12/31/12 21:30    12

# %%
crime_count = pd.DataFrame(train.groupby('Beat').size().sort_values(ascending=True))
crime_count
# Out:
#          0
# Beat
# 130      1
# 1221     5
# 114      5
# 1214     7
# 1225     8
# ...    ...
# 824   1441
# 2521  1518
# 831   1564
# 823   1616
# 2512  1619
#
# [300 rows x 1 columns]

# %%
x=train['Date'].sort_values(ascending=False)
y=train['Beat'].sort_values(ascending=False)

plt.plot(x.head(),y.head(),'b',label="line",linewidth=10)

plt.bar(x.head(),y.head(),color='g',label="bar1")
plt.ylabel('y-axis')
plt.xlabel('x-axis')
plt.title('info')
plt.grid(True,color='c')
plt.legend()
plt.show()

# %%
max(train.Beat)
# Out:
# 2535
